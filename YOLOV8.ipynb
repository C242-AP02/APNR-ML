# %% [markdown]
# **INSTALL LIBRARY ULTRALIYTICS DAN PEMERIKSAAN GPU KOMPUTER**

# %%
# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 33.4/235.7 GB disk)

# %% [markdown]
# **IMPORT LIBRARY YANG DIBUTUHKAN**

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# **INSTALL LIBRARY ROBOFLOW DAN IMPORT DATASET DARI ROBOFLOW**

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="vZXhBKPSUAlk4dnmLZSU")
# project = rf.workspace("apnr-wur85").project("apnr-my0zl")
# version = project.version(2)
# dataset = version.download("yolov8")
from roboflow import Roboflow
rf = Roboflow(api_key="zYGUQb1uL87SwbWS1kiU")
project = rf.workspace("c242ap02capstone").project("number-plate-detection-aj1tz")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# **TRAIN MENGGUNAKAN YOLOV8L DAN FINETUNE HYPERPARAMETER**

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/content/Number-Plate-Detection-2/data.yaml epochs=100 imgsz=640 batch=32 optimizer=AdamW
# Out:
# New https://pypi.org/project/ultralytics/8.3.40 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# **VALIDASI MENGGUNAKAN MODEL YANG TELAH DI TRAIN**

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train3/weights/best.pt data=/content/Number-Plate-Detection-2/data.yaml
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 268 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /content/Number-Plate-Detection-2/valid/labels.cache... 354 images, 0 backgrounds, 0 corrupt: 100% 354/354 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 33, len(boxes) = 395. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:03<00:00,  5.84it/s]
#                    all        354        395      0.968      0.967      0.985      0.824
# Speed: 0.7ms preprocess, 4.1ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val
